# %% [markdown]
# <a href="https://colab.research.google.com/github/elazzaouisofiane/01DataMiningTest/blob/main/12DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn import metrics

# %%
centers = [[-1, -1], [1,1],[-1,1]]
X, labels_true = make_blobs(n_samples = 500, centers=centers, cluster_std=0.5, random_state=0)

X = StandardScaler().fit_transform(X)

# %%
plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %%
db = DBSCAN(eps=0.2, min_samples=10).fit(X)
labels = db.labels_

n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
# Out:
# Estimated number of clusters: 7
# Estimated number of noise points: 180

# %%
print(f"Silhouette Coefficient: {metrics.silhouette_score(X,labels):.3f}")
# Out:
# Silhouette Coefficient: -0.010

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.show()

# %%
db = DBSCAN(eps=0.2, min_samples=8).fit(X)
labels = db.labels_

n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
# Out:
# Estimated number of clusters: 4
# Estimated number of noise points: 142

# %%
print(f"Silhouette Coefficient: {metrics.silhouette_score(X,labels):.3f}")
# Out:
# Silhouette Coefficient: 0.230

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.show()

# %%
db = DBSCAN(eps=0.2, min_samples=7).fit(X)
labels = db.labels_

n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
# Out:
# Estimated number of clusters: 5
# Estimated number of noise points: 124

# %%
print(f"Silhouette Coefficient: {metrics.silhouette_score(X,labels):.3f}")
# Out:
# Silhouette Coefficient: 0.168

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.show()

# %%
db = DBSCAN(eps=0.3, min_samples=8).fit(X)
labels = db.labels_

n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
# Out:
# Estimated number of clusters: 1
# Estimated number of noise points: 35

# %%
print(f"Silhouette Coefficient: {metrics.silhouette_score(X,labels):.3f}")
# Out:
# Silhouette Coefficient: 0.137

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.show()

# %%
db = DBSCAN(eps=0.3, min_samples=3).fit(X)
labels = db.labels_

n_clusters_ = len(set(labels)) - (1 if -1 in labels else 8)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
# Out:
# Estimated number of clusters: 3
# Estimated number of noise points: 8

# %%
print(f"Silhouette Coefficient: {metrics.silhouette_score(X,labels):.3f}")
# Out:
# Silhouette Coefficient: -0.043

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels)
plt.show()
