# %% [markdown]
# <a href="https://colab.research.google.com/github/elazzaouisofiane/01DataMiningTest/blob/main/1DMTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/Breast_Cancer_Data.csv')
df.head(5)
# Out:
#    mean_radius  mean_texture  mean_perimeter  mean_area  mean_smoothness
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030

# %%
file = open('Arden.txt', 'r')

for each in file:
  print(each)
# Out:
# When we show up to the present moment with all of our senses, we invite the world to fill us with joy.
# The pains of the past are behind us.
# The future has yet to unfold.
# But the now is full of beauty simply waiting for our attention.

# %%
file = open("Arden.txt", "r")



print (file.read())
# Out:
# When we show up to the present moment with all of our senses, we invite the world to fill us with joy.
# The pains of the past are behind us.
# The future has yet to unfold.
# But the now is full of beauty simply waiting for our attention.

# %%
# Python code to illustrate character read() mode

fs = open(r"Arden.txt", 'r')

# Read the 4 characters from the text file

con = fs.read(4)

# Read the 10 characters from the text file

con1 = fs.read(10)

# Read the entire file

con2 = fs.read()

print (con)
print (con1)
print (con2)

fs.close() #It will read the entire file
# Out:
# When
#  we show u
# p to the present moment with all of our senses, we invite the world to fill us with joy.
# The pains of the past are behind us.
# The future has yet to unfold.
# But the now is full of beauty simply waiting for our attention.

# %%
# Python code to create a file



file = open("WriteCommand.txt", 'w')



file.write("This is the write command")



file.write("Allows the user to write in a particular file")



file.close()

# %%
# Python code to illustrate with () along with write()



with open("file.txt", 'w') as f:



  f.write("Hello Arden University!")

# %%
# Python program to show basic array characteristics
import numpy as np



# Creating array object

arr = np.array([[ 1, 2, 3],[ 4, 2, 5]])



# Printing type of arr object

print("Array is of type: ", type(arr))



# Printing array dimensions (axes)

print("No. of dimensions: ", arr.ndim)



# Printing shape of array

print("Shape of array: ", arr.shape)



# Printing size (total number of elements) of array

print("Size of array: ", arr.size)



# Printing type of elements in array

print("Array stores elements of type: ", arr.dtype)
# Out:
# Array is of type:  <class 'numpy.ndarray'>
# No. of dimensions:  2
# Shape of array:  (2, 3)
# Size of array:  6
# Array stores elements of type:  int64

# %%
# Python program to show indexing in numpy array

import numpy as np



# Initial Array

arr = np.array([[-1, 2, 0, 4],



[4, -0.5, 6, 0],



[2.6, 0, 7, 8],



[3, -7, 4, 2.0]])



print("Initial Array: ")



print(arr)



# Printing the range of an Array with the use of the slicing methodology

sliced_arr = arr[:2, ::2]

print ("Array with first 2 rows and"



" alternate columns(0 and 2):\n", sliced_arr)



# Printing elements at specific Indices

Index_arr = arr[[1, 1, 0, 3],



[3, 2, 1, 0]]



print ("\nElements at indices (1, 3), "

"(1, 2), (0, 1), (3, 0):\n", Index_arr)
# Out:
# Initial Array:
# [[-1.   2.   0.   4. ]
#  [ 4.  -0.5  6.   0. ]
#  [ 2.6  0.   7.   8. ]
#  [ 3.  -7.   4.   2. ]]
# Array with first 2 rows and alternate columns(0 and 2):
#  [[-1.  0.]
#  [ 4.  6.]]
#
# Elements at indices (1, 3), (1, 2), (0, 1), (3, 0):
#  [0. 6. 2. 3.]

# %%
# Python program to show basic operations on a single array

import numpy as np



# Defining Array 1

a = np.array([[1, 2],



[3, 4]])



# Defining Array 2

b = np.array([[4, 3],



[2, 1]])



# Adding 1 to every element

print ("Adding 1 to every element:", a + 1)

# Subtracting 2 from each element

print ("\nSubtracting 2 from each element:", b - 2)

# Sum of array elements by performing Unary operations

print ("\nSum of all array elements: ", a.sum())
# Out:
# Adding 1 to every element: [[2 3]
#  [4 5]]
#
# Subtracting 2 from each element: [[ 2  1]
#  [ 0 -1]]
#
# Sum of all array elements:  10

# %%
import pandas as pd

import numpy as np



# Creating empty series mode

ser = pd.Series()



print(ser)



# simple array

data = np.array (['A',  'r', 'd', 'e', 'n'])

ser = pd.Series(data)



print (ser)
# Out:
# Series([], dtype: object)
# 0    A
# 1    r
# 2    d
# 3    e
# 4    n
# dtype: object
